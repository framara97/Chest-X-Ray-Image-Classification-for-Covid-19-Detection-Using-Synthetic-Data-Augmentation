# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import sys
import os
import random
from pathlib import Path

# Image processing
import imageio
import cv2
import skimage.transform


# Charts
import matplotlib.pyplot as plt
import seaborn as sns

# ML, statistics
import scipy
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, Activation, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras import backend as K

# %% [markdown]
# # SETTINGS

# %% [markdown]
# ## Global

# %%
# Settings
plt.style.use('fivethirtyeight')
#plt.style.use('seaborn')

# toy=True - development mode, small samples, limited training, fast run
# toy=False - full data, slow learning and run
toy=False

#set size of validation set and test set in percentage
validation_size = 10
test_size = 10

# Generators Paramenters
batch_size = 32
img_size = (224,224)

# %% [markdown]
# ## Dataset Parameters

# %%
# Dataset Root Path
dataset_path = "../input/covid19-radiography-database/COVID-19_Radiography_Dataset"

# Folder Paths
covid_path = dataset_path + "/COVID/images"
lungOpacity_path = dataset_path + "/Lung_Opacity/images"
normal_path = dataset_path + "/Normal/images"
viralPneumonia_path = dataset_path + "/Viral Pneumonia/images"

# LABELS LOCAL Array
#labels = ['COVID', 'Lung Opacity', 'Normal', 'Viral Pneumonia']
labels = ['COVID', 'Normal', 'Viral Pneumonia']

# %% [markdown]
# # DATA PREPARATION

# %%
# Generate Filename list
def filename_list():

    if toy :
        random.seed(100)
        filenames = random.sample(os.listdir(covid_path), 200) + random.sample(os.listdir(lungOpacity_path), 200) + random.sample(os.listdir(normal_path), 200) + random.sample(os.listdir(viralPneumonia_path), 200)
    else :
       #filenames = os.listdir(covid_path) + os.listdir(lungOpacity_path) + os.listdir(normal_path) + os.listdir(viralPneumonia_path)
        filenames = os.listdir(covid_path) + os.listdir(normal_path) + os.listdir(viralPneumonia_path)

    return filenames

# %%
def dataframe_generation(files):
    
    categories = []
    for filename in files:
        category = filename.split('-')[0]
        if category == labels[0]:
            categories.append(str(0))
        elif category == labels[1]:
            categories.append(str(1))
        elif category == labels[2]:
            categories.append(str(2))
        #elif category == labels[3]:
         #   categories.append(str(3))

    for i in range(len(files)):
        if labels[0] in files[i]:
            files[i] = os.path.join(covid_path, files[i])
        #elif labels[1] in files[i]:
            #files[i] = os.path.join(lungOpacity_path, files[i])
        elif labels[1] in files[i]:
            files[i] = os.path.join(normal_path, files[i])
        elif labels[2] in files[i]:
            files[i] = os.path.join(viralPneumonia_path, files[i])
    
    df = pd.DataFrame({
        'filename': files,
        'category': categories
    })

    return df

# %% [markdown]
# ## Generate Dataset

# %%
filenames = filename_list()
dataset_df = dataframe_generation(filenames)

dataset_df.head()
# Out:
#                                             filename category
# 0  ../input/covid19-radiography-database/COVID-19...        0
# 1  ../input/covid19-radiography-database/COVID-19...        0
# 2  ../input/covid19-radiography-database/COVID-19...        0
# 3  ../input/covid19-radiography-database/COVID-19...        0
# 4  ../input/covid19-radiography-database/COVID-19...        0

# %%
def read_img(id):
    """
    Read image by it's id
    """
    file=id
    im=cv2.imread(file)
    return im

def draw_sample_images(dataframe, ncols, labels):

        ncols=ncols
        n_rows = len(labels)

        f, ax = plt.subplots(nrows=n_rows,ncols=ncols, 
                             figsize=(4*ncols,5*2))
        i=-1
        captions=labels
        
        for label in range(n_rows):
            i=i+1
            samples = dataframe[dataframe["category"].astype(int) == label].filename.sample(ncols).values
            for j in range(0,ncols):
                file_id=samples[j]
                im=read_img(file_id)
                ax[i, j].imshow(im)
                ax[i, j].set_title(captions[i], fontsize=16)  
        plt.tight_layout()
        plt.show()

# %%
def plot_data_distribution(dataframe):
    y = np.bincount(dataframe.category)
    x = labels
    fig, ax = plt.subplots(figsize=(10,8))
    plt.bar(x, y,width=0.7)
    ax.set_xticks(x)
    ax.set_aspect('auto')
    plt.show()

# %%
draw_sample_images(dataset_df, 4, labels)
plot_data_distribution(dataset_df)

# %% [markdown]
# ## Dataset Balancing

# %%
def data_reduction(size):
    random.seed(100)
    reduced_dataset = random.sample(os.listdir(covid_path), size) + random.sample(os.listdir(normal_path), size) + random.sample(os.listdir(viralPneumonia_path), size)

    df_reduced = dataframe_generation(reduced_dataset)

    return df_reduced

# %%
df_Reduced = data_reduction(1000)
plot_data_distribution(df_Reduced)

# %% [markdown]
# ## Split in Train, Validation and Test

# %%
def sets_split(dataframe):
    x_1_split = (validation_size + test_size)/100
    x_2_split = round(test_size / (validation_size + test_size), 2)

    train_df, valTest_df = train_test_split(dataframe, test_size=x_1_split, random_state=24)
    val_df, test_df = train_test_split(valTest_df, test_size=x_2_split, random_state=24)

    return train_df, val_df, test_df

# %%
train, validation, test = sets_split(dataset_df)

# %% [markdown]
# ## Generators

# %%
_datagen = ImageDataGenerator(
            rotation_range=15,
            rescale=1./255,
            shear_range=0.1,
            zoom_range=0.2,
            horizontal_flip=True,
            width_shift_range=0.1,
            height_shift_range=0.1   
            )

_test_datagen=ImageDataGenerator(rescale=1./255)

# %%
train_generator = _datagen.flow_from_dataframe(
            dataframe=train,
            x_col="filename",
            y_col="category",
            batch_size=batch_size,
            seed=42,
            shuffle=True,
            class_mode="categorical",
            color_mode="rgb",
            target_size=img_size)
print('Train generator created')
# Out:
# Found 12122 validated image filenames belonging to 3 classes.
# Train generator created

# %%
val_generator = _test_datagen.flow_from_dataframe(
            dataframe=validation,
            x_col="filename",
            y_col="category",
            batch_size=batch_size,
            seed=42,
            shuffle=True,
            class_mode="categorical",
            color_mode="rgb",
            target_size=img_size)    
print('Validation generator created')
# Out:
# Found 1515 validated image filenames belonging to 3 classes.
# Validation generator created

# %%
test_generator = _test_datagen.flow_from_dataframe(
            dataframe=test,
            x_col="filename",
            y_col=None,
            class_mode=None,
            batch_size=batch_size,
            seed=42,
            shuffle=False,
            color_mode="rgb",
            target_size=img_size)     
print('Test generator created')
# Out:
# Found 1516 validated image filenames.
# Test generator created

# %% [markdown]
# # MODEL GENERATION

# %% [markdown]
# ## Metrics Aux Functions

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## Model Creation

# %%
def create_model(size):
        base_model = ResNet50(input_shape= (size,size,3), weights="imagenet", include_top=False)
        
        for layer in base_model.layers:
            layer.trainable = False

        x=base_model.output
        x=GlobalAveragePooling2D()(x)
        x = Dense(128, activation='relu')(x)
        x = Dense(64, activation='relu')(x)
        x= Dropout(0.5)(x)
        out=Dense(3,activation='softmax')(x)

        model=Model(inputs=base_model.input,outputs=out) 
            
        model.compile(optimizer= Adam(0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy', f1_m, precision_m, recall_m])
        
        return model

# %%
model = create_model(224)
model.summary()
# Out:
# 2022-05-24 08:22:34.060930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:34.184090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:34.184950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:34.186476: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-24 08:22:34.187701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:34.188387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:34.189058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:36.412985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:36.413911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:36.414580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-24 08:22:36.415208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          262272      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dense[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            195         dropout[0][0]
# ==================================================================================================
# Total params: 23,858,435
# Trainable params: 270,723
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define Trainer

# %%
from keras.callbacks import Callback
import matplotlib.pyplot as plt    
import matplotlib.patches as mpatches  
from sklearn.metrics import confusion_matrix
import itertools
import numpy as np


class AccLossPlotter(Callback):
    """Plot training Accuracy and Loss values on a Matplotlib graph. 
    The graph is updated by the 'on_epoch_end' event of the Keras Callback class
    # Arguments
        graphs: list with some or all of ('acc', 'loss')
        save_graph: Save graph as an image on Keras Callback 'on_train_end' event 
    """

    def __init__(self, graphs=['acc', 'loss'], save_graph=False):
        self.graphs = graphs
        self.num_subplots = len(graphs)
        self.save_graph = save_graph


    def on_train_begin(self, logs={}):
        self.acc = []
        self.val_acc = []
        self.loss = []
        self.val_loss = []
        self.epoch_count = 0
        plt.ion()
        plt.show()


    def on_epoch_end(self, epoch, logs={}):
        self.epoch_count += 1
        self.val_acc.append(logs.get('val_acc'))
        self.acc.append(logs.get('acc'))
        self.loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))
        epochs = [x for x in range(self.epoch_count)]

        count_subplots = 0
        
        if 'acc' in self.graphs:
            count_subplots += 1
            plt.subplot(self.num_subplots, 1, count_subplots)
            plt.title('Accuracy')
            #plt.axis([0,100,0,1])
            plt.plot(epochs, self.val_acc, color='r')
            plt.plot(epochs, self.acc, color='b')
            plt.ylabel('accuracy')

            red_patch = mpatches.Patch(color='red', label='Test')
            blue_patch = mpatches.Patch(color='blue', label='Train')

            plt.legend(handles=[red_patch, blue_patch], loc=4)

        if 'loss' in self.graphs:
            count_subplots += 1
            plt.subplot(self.num_subplots, 1, count_subplots)
            plt.title('Loss')
            #plt.axis([0,100,0,5])
            plt.plot(epochs, self.val_loss, color='r')
            plt.plot(epochs, self.loss, color='b')
            plt.ylabel('loss')

            red_patch = mpatches.Patch(color='red', label='Test')
            blue_patch = mpatches.Patch(color='blue', label='Train')

            plt.legend(handles=[red_patch, blue_patch], loc=4)
        
        plt.draw()
        plt.pause(0.001)

    def on_train_end(self, logs={}):
        if self.save_graph:
            plt.savefig('training_acc_loss.png')

class ConfusionMatrixPlotter(Callback):
    """Plot the confusion matrix on a graph and update after each epoch
    # Arguments
        X_val: The input values 
        Y_val: The expected output values
        classes: The categories as a list of string names
        normalize: True - normalize to [0,1], False - keep as is
        cmap: Specify matplotlib colour map
        title: Graph Title
    """
    def __init__(self, X_val, Y_val, classes, normalize=False, cmap=plt.cm.Blues, title='Confusion Matrix'):
        self.X_val = X_val
        self.Y_val = Y_val
        self.title = title
        self.classes = classes
        self.normalize = normalize
        self.cmap = cmap
        plt.ion()
        #plt.show()
        #plt.figure()

        #plt.title(self.title)
        
        

    def on_train_begin(self, logs={}):
        pass

    
    def on_epoch_end(self, epoch, logs={}):    
        plt.clf()
        pred = self.model.predict(self.X_val)
        max_pred = np.argmax(pred, axis=1)
        max_y = np.argmax(self.Y_val, axis=1)
        cnf_mat = confusion_matrix(max_y, max_pred)
   
        if self.normalize:
            cnf_mat = cnf_mat.astype('float') / cnf_mat.sum(axis=1)[:, np.newaxis]

        thresh = cnf_mat.max() / 2.
        for i, j in itertools.product(range(cnf_mat.shape[0]), range(cnf_mat.shape[1])):
            plt.text(j, i, cnf_mat[i, j],                                          
                         horizontalalignment="center",
                         color="white" if cnf_mat[i, j] > thresh else "black")

        plt.imshow(cnf_mat, interpolation='nearest', cmap=self.cmap)

        # Labels
        tick_marks = np.arange(len(self.classes))
        plt.xticks(tick_marks, self.classes, rotation=45)
        plt.yticks(tick_marks, self.classes)

        plt.colorbar()
                                                                                                         
        plt.tight_layout()                                                    
        plt.ylabel('True label')                                              
        plt.xlabel('Predicted label')                                         
        #plt.draw()
        plt.show()
        plt.pause(0.001)

# %%
plotter = ConfusionMatrixPlotter(X_val=validation.filename.values, classes=labels, Y_val=validation.category.values)

# %%
def train(model, train_data, val_data, toy):
        """
        Train the model
        """
        if toy:
            epochs=3

        else:
            epochs=100
            
        # We'll stop training if no improvement after some epochs
        earlystopper = EarlyStopping(monitor='val_loss', mode='min', patience=5 , restore_best_weights=True)

        # Save the best model during the traning
        checkpointer = ModelCheckpoint('best_model1.h5'
                                        ,monitor='val_loss'
                                        ,mode='min'
                                        ,verbose=1
                                        ,save_best_only=True)
        # Train
        training = model.fit(train_data, 
                            validation_data = val_data, 
                            epochs = epochs, 
                            verbose = 1,
                            batch_size = batch_size,
                            callbacks=[earlystopper, checkpointer])
        
        print("Trained")
                            
        return training

# %%
trained = train(model, train_generator, val_generator, toy)
# Out:
# 2022-05-24 08:22:39.789058: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-05-24 08:22:44.137926: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 379/379 [==============================] - 238s 604ms/step - loss: 0.8722 - accuracy: 0.6581 - f1_m: 0.6269 - precision_m: 0.6693 - recall_m: 0.5916 - val_loss: 0.8110 - val_accuracy: 0.6799 - val_f1_m: 0.6780 - val_precision_m: 0.6780 - val_recall_m: 0.6780
#
# Epoch 00001: val_loss improved from inf to 0.81103, saving model to best_model1.h5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 379/379 [==============================] - 163s 429ms/step - loss: 0.8422 - accuracy: 0.6710 - f1_m: 0.6509 - precision_m: 0.6713 - recall_m: 0.6325 - val_loss: 0.8000 - val_accuracy: 0.6799 - val_f1_m: 0.6768 - val_precision_m: 0.6768 - val_recall_m: 0.6768
#
# Epoch 00002: val_loss improved from 0.81103 to 0.80000, saving model to best_model1.h5
# Epoch 3/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.8342 - accuracy: 0.6722 - f1_m: 0.6603 - precision_m: 0.6758 - recall_m: 0.6460 - val_loss: 0.7957 - val_accuracy: 0.6799 - val_f1_m: 0.6818 - val_precision_m: 0.6818 - val_recall_m: 0.6818
#
# Epoch 00003: val_loss improved from 0.80000 to 0.79568, saving model to best_model1.h5
# Epoch 4/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.8254 - accuracy: 0.6725 - f1_m: 0.6596 - precision_m: 0.6748 - recall_m: 0.6457 - val_loss: 0.7865 - val_accuracy: 0.6799 - val_f1_m: 0.6793 - val_precision_m: 0.6793 - val_recall_m: 0.6793
#
# Epoch 00004: val_loss improved from 0.79568 to 0.78654, saving model to best_model1.h5
# Epoch 5/100
# 379/379 [==============================] - 165s 437ms/step - loss: 0.8143 - accuracy: 0.6722 - f1_m: 0.6620 - precision_m: 0.6754 - recall_m: 0.6497 - val_loss: 0.7818 - val_accuracy: 0.6799 - val_f1_m: 0.6842 - val_precision_m: 0.6842 - val_recall_m: 0.6842
#
# Epoch 00005: val_loss improved from 0.78654 to 0.78178, saving model to best_model1.h5
# Epoch 6/100
# 379/379 [==============================] - 166s 439ms/step - loss: 0.8111 - accuracy: 0.6724 - f1_m: 0.6609 - precision_m: 0.6741 - recall_m: 0.6487 - val_loss: 0.7681 - val_accuracy: 0.6799 - val_f1_m: 0.6805 - val_precision_m: 0.6805 - val_recall_m: 0.6805
#
# Epoch 00006: val_loss improved from 0.78178 to 0.76806, saving model to best_model1.h5
# Epoch 7/100
# 379/379 [==============================] - 164s 434ms/step - loss: 0.8047 - accuracy: 0.6726 - f1_m: 0.6623 - precision_m: 0.6766 - recall_m: 0.6493 - val_loss: 0.7663 - val_accuracy: 0.6799 - val_f1_m: 0.6805 - val_precision_m: 0.6805 - val_recall_m: 0.6805
#
# Epoch 00007: val_loss improved from 0.76806 to 0.76629, saving model to best_model1.h5
# Epoch 8/100
# 379/379 [==============================] - 163s 431ms/step - loss: 0.7956 - accuracy: 0.6728 - f1_m: 0.6599 - precision_m: 0.6826 - recall_m: 0.6401 - val_loss: 0.7559 - val_accuracy: 0.6799 - val_f1_m: 0.6805 - val_precision_m: 0.6805 - val_recall_m: 0.6805
#
# Epoch 00008: val_loss improved from 0.76629 to 0.75591, saving model to best_model1.h5
# Epoch 9/100
# 379/379 [==============================] - 164s 432ms/step - loss: 0.7911 - accuracy: 0.6732 - f1_m: 0.6606 - precision_m: 0.6799 - recall_m: 0.6435 - val_loss: 0.7526 - val_accuracy: 0.6799 - val_f1_m: 0.6830 - val_precision_m: 0.6830 - val_recall_m: 0.6830
#
# Epoch 00009: val_loss improved from 0.75591 to 0.75259, saving model to best_model1.h5
# Epoch 10/100
# 379/379 [==============================] - 162s 427ms/step - loss: 0.7860 - accuracy: 0.6722 - f1_m: 0.6593 - precision_m: 0.6849 - recall_m: 0.6367 - val_loss: 0.7517 - val_accuracy: 0.6799 - val_f1_m: 0.6805 - val_precision_m: 0.6805 - val_recall_m: 0.6805
#
# Epoch 00010: val_loss improved from 0.75259 to 0.75166, saving model to best_model1.h5
# Epoch 11/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.7856 - accuracy: 0.6749 - f1_m: 0.6611 - precision_m: 0.6860 - recall_m: 0.6395 - val_loss: 0.7401 - val_accuracy: 0.6799 - val_f1_m: 0.6783 - val_precision_m: 0.6785 - val_recall_m: 0.6780
#
# Epoch 00011: val_loss improved from 0.75166 to 0.74008, saving model to best_model1.h5
# Epoch 12/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.7810 - accuracy: 0.6724 - f1_m: 0.6585 - precision_m: 0.6870 - recall_m: 0.6335 - val_loss: 0.7393 - val_accuracy: 0.6799 - val_f1_m: 0.6719 - val_precision_m: 0.7049 - val_recall_m: 0.6428
#
# Epoch 00012: val_loss improved from 0.74008 to 0.73925, saving model to best_model1.h5
# Epoch 13/100
# 379/379 [==============================] - 164s 431ms/step - loss: 0.7769 - accuracy: 0.6708 - f1_m: 0.6556 - precision_m: 0.6873 - recall_m: 0.6286 - val_loss: 0.7366 - val_accuracy: 0.6799 - val_f1_m: 0.6805 - val_precision_m: 0.6805 - val_recall_m: 0.6805
#
# Epoch 00013: val_loss improved from 0.73925 to 0.73665, saving model to best_model1.h5
# Epoch 14/100
# 379/379 [==============================] - 166s 439ms/step - loss: 0.7710 - accuracy: 0.6711 - f1_m: 0.6566 - precision_m: 0.6868 - recall_m: 0.6302 - val_loss: 0.7235 - val_accuracy: 0.6799 - val_f1_m: 0.6762 - val_precision_m: 0.6946 - val_recall_m: 0.6591
#
# Epoch 00014: val_loss improved from 0.73665 to 0.72355, saving model to best_model1.h5
# Epoch 15/100
# 379/379 [==============================] - 165s 436ms/step - loss: 0.7627 - accuracy: 0.6765 - f1_m: 0.6562 - precision_m: 0.6934 - recall_m: 0.6250 - val_loss: 0.7210 - val_accuracy: 0.6818 - val_f1_m: 0.6707 - val_precision_m: 0.7122 - val_recall_m: 0.6351
#
# Epoch 00015: val_loss improved from 0.72355 to 0.72097, saving model to best_model1.h5
# Epoch 16/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.7664 - accuracy: 0.6724 - f1_m: 0.6578 - precision_m: 0.6900 - recall_m: 0.6299 - val_loss: 0.7117 - val_accuracy: 0.6799 - val_f1_m: 0.6821 - val_precision_m: 0.6878 - val_recall_m: 0.6766
#
# Epoch 00016: val_loss improved from 0.72097 to 0.71175, saving model to best_model1.h5
# Epoch 17/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.7552 - accuracy: 0.6764 - f1_m: 0.6581 - precision_m: 0.6959 - recall_m: 0.6262 - val_loss: 0.7058 - val_accuracy: 0.6799 - val_f1_m: 0.6784 - val_precision_m: 0.6928 - val_recall_m: 0.6650
#
# Epoch 00017: val_loss improved from 0.71175 to 0.70577, saving model to best_model1.h5
# Epoch 18/100
# 379/379 [==============================] - 163s 431ms/step - loss: 0.7531 - accuracy: 0.6709 - f1_m: 0.6580 - precision_m: 0.6933 - recall_m: 0.6284 - val_loss: 0.7079 - val_accuracy: 0.6799 - val_f1_m: 0.6797 - val_precision_m: 0.6802 - val_recall_m: 0.6793
#
# Epoch 00018: val_loss did not improve from 0.70577
# Epoch 19/100
# 379/379 [==============================] - 165s 434ms/step - loss: 0.7460 - accuracy: 0.6743 - f1_m: 0.6578 - precision_m: 0.6955 - recall_m: 0.6262 - val_loss: 0.6910 - val_accuracy: 0.6799 - val_f1_m: 0.6840 - val_precision_m: 0.6884 - val_recall_m: 0.6798
#
# Epoch 00019: val_loss improved from 0.70577 to 0.69104, saving model to best_model1.h5
# Epoch 20/100
# 379/379 [==============================] - 163s 431ms/step - loss: 0.7424 - accuracy: 0.6743 - f1_m: 0.6570 - precision_m: 0.6952 - recall_m: 0.6247 - val_loss: 0.6910 - val_accuracy: 0.6878 - val_f1_m: 0.6691 - val_precision_m: 0.7394 - val_recall_m: 0.6135
#
# Epoch 00020: val_loss improved from 0.69104 to 0.69098, saving model to best_model1.h5
# Epoch 21/100
# 379/379 [==============================] - 167s 441ms/step - loss: 0.7338 - accuracy: 0.6727 - f1_m: 0.6586 - precision_m: 0.6959 - recall_m: 0.6270 - val_loss: 0.6779 - val_accuracy: 0.6799 - val_f1_m: 0.6808 - val_precision_m: 0.6871 - val_recall_m: 0.6748
#
# Epoch 00021: val_loss improved from 0.69098 to 0.67786, saving model to best_model1.h5
# Epoch 22/100
# 379/379 [==============================] - 166s 436ms/step - loss: 0.7297 - accuracy: 0.6747 - f1_m: 0.6597 - precision_m: 0.6964 - recall_m: 0.6284 - val_loss: 0.6697 - val_accuracy: 0.6891 - val_f1_m: 0.6750 - val_precision_m: 0.6993 - val_recall_m: 0.6533
#
# Epoch 00022: val_loss improved from 0.67786 to 0.66971, saving model to best_model1.h5
# Epoch 23/100
# 379/379 [==============================] - 163s 431ms/step - loss: 0.7257 - accuracy: 0.6735 - f1_m: 0.6587 - precision_m: 0.7036 - recall_m: 0.6220 - val_loss: 0.6629 - val_accuracy: 0.6825 - val_f1_m: 0.6792 - val_precision_m: 0.6953 - val_recall_m: 0.6643
#
# Epoch 00023: val_loss improved from 0.66971 to 0.66286, saving model to best_model1.h5
# Epoch 24/100
# 379/379 [==============================] - 162s 426ms/step - loss: 0.7211 - accuracy: 0.6725 - f1_m: 0.6615 - precision_m: 0.6982 - recall_m: 0.6306 - val_loss: 0.6675 - val_accuracy: 0.6845 - val_f1_m: 0.6797 - val_precision_m: 0.7496 - val_recall_m: 0.6232
#
# Epoch 00024: val_loss did not improve from 0.66286
# Epoch 25/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.7152 - accuracy: 0.6737 - f1_m: 0.6591 - precision_m: 0.7053 - recall_m: 0.6212 - val_loss: 0.6477 - val_accuracy: 0.6799 - val_f1_m: 0.6746 - val_precision_m: 0.7049 - val_recall_m: 0.6475
#
# Epoch 00025: val_loss improved from 0.66286 to 0.64770, saving model to best_model1.h5
# Epoch 26/100
# 379/379 [==============================] - 164s 432ms/step - loss: 0.7035 - accuracy: 0.6770 - f1_m: 0.6624 - precision_m: 0.7086 - recall_m: 0.6241 - val_loss: 0.6483 - val_accuracy: 0.6799 - val_f1_m: 0.6830 - val_precision_m: 0.6903 - val_recall_m: 0.6760
#
# Epoch 00026: val_loss did not improve from 0.64770
# Epoch 27/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6997 - accuracy: 0.6753 - f1_m: 0.6616 - precision_m: 0.7121 - recall_m: 0.6198 - val_loss: 0.6481 - val_accuracy: 0.6799 - val_f1_m: 0.6814 - val_precision_m: 0.6864 - val_recall_m: 0.6767
#
# Epoch 00027: val_loss did not improve from 0.64770
# Epoch 28/100
# 379/379 [==============================] - 162s 427ms/step - loss: 0.6983 - accuracy: 0.6752 - f1_m: 0.6586 - precision_m: 0.7124 - recall_m: 0.6158 - val_loss: 0.6217 - val_accuracy: 0.6845 - val_f1_m: 0.6835 - val_precision_m: 0.7228 - val_recall_m: 0.6493
#
# Epoch 00028: val_loss improved from 0.64770 to 0.62172, saving model to best_model1.h5
# Epoch 29/100
# 379/379 [==============================] - 162s 426ms/step - loss: 0.6900 - accuracy: 0.6768 - f1_m: 0.6626 - precision_m: 0.7160 - recall_m: 0.6190 - val_loss: 0.6260 - val_accuracy: 0.6865 - val_f1_m: 0.6867 - val_precision_m: 0.7398 - val_recall_m: 0.6423
#
# Epoch 00029: val_loss did not improve from 0.62172
# Epoch 30/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.6868 - accuracy: 0.6778 - f1_m: 0.6620 - precision_m: 0.7184 - recall_m: 0.6166 - val_loss: 0.6173 - val_accuracy: 0.7089 - val_f1_m: 0.6846 - val_precision_m: 0.7636 - val_recall_m: 0.6225
#
# Epoch 00030: val_loss improved from 0.62172 to 0.61731, saving model to best_model1.h5
# Epoch 31/100
# 379/379 [==============================] - 163s 429ms/step - loss: 0.6772 - accuracy: 0.6825 - f1_m: 0.6637 - precision_m: 0.7233 - recall_m: 0.6157 - val_loss: 0.6053 - val_accuracy: 0.7017 - val_f1_m: 0.6863 - val_precision_m: 0.7625 - val_recall_m: 0.6258
#
# Epoch 00031: val_loss improved from 0.61731 to 0.60528, saving model to best_model1.h5
# Epoch 32/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.6704 - accuracy: 0.6829 - f1_m: 0.6648 - precision_m: 0.7262 - recall_m: 0.6164 - val_loss: 0.6012 - val_accuracy: 0.7122 - val_f1_m: 0.6867 - val_precision_m: 0.7565 - val_recall_m: 0.6310
#
# Epoch 00032: val_loss improved from 0.60528 to 0.60122, saving model to best_model1.h5
# Epoch 33/100
# 379/379 [==============================] - 165s 435ms/step - loss: 0.6700 - accuracy: 0.6845 - f1_m: 0.6654 - precision_m: 0.7246 - recall_m: 0.6176 - val_loss: 0.5968 - val_accuracy: 0.7109 - val_f1_m: 0.6851 - val_precision_m: 0.7398 - val_recall_m: 0.6398
#
# Epoch 00033: val_loss improved from 0.60122 to 0.59681, saving model to best_model1.h5
# Epoch 34/100
# 379/379 [==============================] - 162s 427ms/step - loss: 0.6682 - accuracy: 0.6869 - f1_m: 0.6670 - precision_m: 0.7264 - recall_m: 0.6204 - val_loss: 0.6376 - val_accuracy: 0.7228 - val_f1_m: 0.6712 - val_precision_m: 0.7993 - val_recall_m: 0.5811
#
# Epoch 00034: val_loss did not improve from 0.59681
# Epoch 35/100
# 379/379 [==============================] - 163s 429ms/step - loss: 0.6616 - accuracy: 0.6925 - f1_m: 0.6686 - precision_m: 0.7300 - recall_m: 0.6193 - val_loss: 0.6210 - val_accuracy: 0.7432 - val_f1_m: 0.6955 - val_precision_m: 0.8158 - val_recall_m: 0.6082
#
# Epoch 00035: val_loss did not improve from 0.59681
# Epoch 36/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6624 - accuracy: 0.6855 - f1_m: 0.6697 - precision_m: 0.7300 - recall_m: 0.6214 - val_loss: 0.6009 - val_accuracy: 0.7333 - val_f1_m: 0.7121 - val_precision_m: 0.7830 - val_recall_m: 0.6544
#
# Epoch 00036: val_loss did not improve from 0.59681
# Epoch 37/100
# 379/379 [==============================] - 163s 431ms/step - loss: 0.6600 - accuracy: 0.6878 - f1_m: 0.6724 - precision_m: 0.7313 - recall_m: 0.6255 - val_loss: 0.6206 - val_accuracy: 0.7294 - val_f1_m: 0.7146 - val_precision_m: 0.7771 - val_recall_m: 0.6635
#
# Epoch 00037: val_loss did not improve from 0.59681
# Epoch 38/100
# 379/379 [==============================] - 163s 429ms/step - loss: 0.6525 - accuracy: 0.6930 - f1_m: 0.6721 - precision_m: 0.7283 - recall_m: 0.6266 - val_loss: 0.5889 - val_accuracy: 0.7307 - val_f1_m: 0.7075 - val_precision_m: 0.7776 - val_recall_m: 0.6506
#
# Epoch 00038: val_loss improved from 0.59681 to 0.58892, saving model to best_model1.h5
# Epoch 39/100
# 379/379 [==============================] - 163s 429ms/step - loss: 0.6496 - accuracy: 0.6916 - f1_m: 0.6735 - precision_m: 0.7335 - recall_m: 0.6247 - val_loss: 0.5867 - val_accuracy: 0.7155 - val_f1_m: 0.7133 - val_precision_m: 0.7358 - val_recall_m: 0.6928
#
# Epoch 00039: val_loss improved from 0.58892 to 0.58666, saving model to best_model1.h5
# Epoch 40/100
# 379/379 [==============================] - 162s 427ms/step - loss: 0.6432 - accuracy: 0.6929 - f1_m: 0.6775 - precision_m: 0.7345 - recall_m: 0.6313 - val_loss: 0.5720 - val_accuracy: 0.7413 - val_f1_m: 0.7085 - val_precision_m: 0.7809 - val_recall_m: 0.6500
#
# Epoch 00040: val_loss improved from 0.58666 to 0.57197, saving model to best_model1.h5
# Epoch 41/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.6431 - accuracy: 0.6945 - f1_m: 0.6798 - precision_m: 0.7318 - recall_m: 0.6369 - val_loss: 0.5652 - val_accuracy: 0.7307 - val_f1_m: 0.7122 - val_precision_m: 0.7615 - val_recall_m: 0.6700
#
# Epoch 00041: val_loss improved from 0.57197 to 0.56517, saving model to best_model1.h5
# Epoch 42/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6383 - accuracy: 0.6988 - f1_m: 0.6819 - precision_m: 0.7350 - recall_m: 0.6379 - val_loss: 0.5634 - val_accuracy: 0.7287 - val_f1_m: 0.7106 - val_precision_m: 0.7471 - val_recall_m: 0.6787
#
# Epoch 00042: val_loss improved from 0.56517 to 0.56343, saving model to best_model1.h5
# Epoch 43/100
# 379/379 [==============================] - 164s 432ms/step - loss: 0.6443 - accuracy: 0.6999 - f1_m: 0.6775 - precision_m: 0.7334 - recall_m: 0.6322 - val_loss: 0.5586 - val_accuracy: 0.7366 - val_f1_m: 0.7124 - val_precision_m: 0.7596 - val_recall_m: 0.6721
#
# Epoch 00043: val_loss improved from 0.56343 to 0.55857, saving model to best_model1.h5
# Epoch 44/100
# 379/379 [==============================] - 165s 436ms/step - loss: 0.6343 - accuracy: 0.6994 - f1_m: 0.6793 - precision_m: 0.7315 - recall_m: 0.6361 - val_loss: 0.5545 - val_accuracy: 0.7353 - val_f1_m: 0.7176 - val_precision_m: 0.7621 - val_recall_m: 0.6793
#
# Epoch 00044: val_loss improved from 0.55857 to 0.55453, saving model to best_model1.h5
# Epoch 45/100
# 379/379 [==============================] - 164s 433ms/step - loss: 0.6387 - accuracy: 0.7005 - f1_m: 0.6815 - precision_m: 0.7342 - recall_m: 0.6381 - val_loss: 0.5739 - val_accuracy: 0.7083 - val_f1_m: 0.7106 - val_precision_m: 0.7241 - val_recall_m: 0.6981
#
# Epoch 00045: val_loss did not improve from 0.55453
# Epoch 46/100
# 379/379 [==============================] - 165s 436ms/step - loss: 0.6310 - accuracy: 0.7012 - f1_m: 0.6853 - precision_m: 0.7399 - recall_m: 0.6403 - val_loss: 0.5511 - val_accuracy: 0.7347 - val_f1_m: 0.7198 - val_precision_m: 0.7489 - val_recall_m: 0.6935
#
# Epoch 00046: val_loss improved from 0.55453 to 0.55109, saving model to best_model1.h5
# Epoch 47/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.6277 - accuracy: 0.7024 - f1_m: 0.6879 - precision_m: 0.7373 - recall_m: 0.6464 - val_loss: 0.5472 - val_accuracy: 0.7399 - val_f1_m: 0.7202 - val_precision_m: 0.7631 - val_recall_m: 0.6832
#
# Epoch 00047: val_loss improved from 0.55109 to 0.54723, saving model to best_model1.h5
# Epoch 48/100
# 379/379 [==============================] - 166s 437ms/step - loss: 0.6244 - accuracy: 0.7024 - f1_m: 0.6851 - precision_m: 0.7349 - recall_m: 0.6432 - val_loss: 0.5651 - val_accuracy: 0.7135 - val_f1_m: 0.7124 - val_precision_m: 0.7282 - val_recall_m: 0.6976
#
# Epoch 00048: val_loss did not improve from 0.54723
# Epoch 49/100
# 379/379 [==============================] - 163s 429ms/step - loss: 0.6235 - accuracy: 0.7043 - f1_m: 0.6892 - precision_m: 0.7391 - recall_m: 0.6474 - val_loss: 0.5541 - val_accuracy: 0.7452 - val_f1_m: 0.7137 - val_precision_m: 0.7912 - val_recall_m: 0.6514
#
# Epoch 00049: val_loss did not improve from 0.54723
# Epoch 50/100
# 379/379 [==============================] - 161s 426ms/step - loss: 0.6272 - accuracy: 0.7033 - f1_m: 0.6885 - precision_m: 0.7382 - recall_m: 0.6470 - val_loss: 0.5383 - val_accuracy: 0.7419 - val_f1_m: 0.7251 - val_precision_m: 0.7682 - val_recall_m: 0.6876
#
# Epoch 00050: val_loss improved from 0.54723 to 0.53830, saving model to best_model1.h5
# Epoch 51/100
# 379/379 [==============================] - 162s 427ms/step - loss: 0.6242 - accuracy: 0.7045 - f1_m: 0.6862 - precision_m: 0.7356 - recall_m: 0.6451 - val_loss: 0.5389 - val_accuracy: 0.7406 - val_f1_m: 0.7278 - val_precision_m: 0.7669 - val_recall_m: 0.6936
#
# Epoch 00051: val_loss did not improve from 0.53830
# Epoch 52/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6198 - accuracy: 0.7088 - f1_m: 0.6935 - precision_m: 0.7387 - recall_m: 0.6551 - val_loss: 0.5356 - val_accuracy: 0.7498 - val_f1_m: 0.7301 - val_precision_m: 0.7695 - val_recall_m: 0.6955
#
# Epoch 00052: val_loss improved from 0.53830 to 0.53561, saving model to best_model1.h5
# Epoch 53/100
# 379/379 [==============================] - 164s 433ms/step - loss: 0.6108 - accuracy: 0.7062 - f1_m: 0.6917 - precision_m: 0.7392 - recall_m: 0.6515 - val_loss: 0.5330 - val_accuracy: 0.7386 - val_f1_m: 0.7204 - val_precision_m: 0.7594 - val_recall_m: 0.6864
#
# Epoch 00053: val_loss improved from 0.53561 to 0.53300, saving model to best_model1.h5
# Epoch 54/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.6153 - accuracy: 0.7069 - f1_m: 0.6910 - precision_m: 0.7375 - recall_m: 0.6518 - val_loss: 0.5427 - val_accuracy: 0.7340 - val_f1_m: 0.7270 - val_precision_m: 0.7518 - val_recall_m: 0.7045
#
# Epoch 00054: val_loss did not improve from 0.53300
# Epoch 55/100
# 379/379 [==============================] - 164s 431ms/step - loss: 0.6106 - accuracy: 0.7094 - f1_m: 0.6957 - precision_m: 0.7402 - recall_m: 0.6579 - val_loss: 0.5440 - val_accuracy: 0.7320 - val_f1_m: 0.7229 - val_precision_m: 0.7512 - val_recall_m: 0.6976
#
# Epoch 00055: val_loss did not improve from 0.53300
# Epoch 56/100
# 379/379 [==============================] - 164s 432ms/step - loss: 0.6154 - accuracy: 0.7049 - f1_m: 0.6929 - precision_m: 0.7374 - recall_m: 0.6549 - val_loss: 0.5301 - val_accuracy: 0.7459 - val_f1_m: 0.7312 - val_precision_m: 0.7664 - val_recall_m: 0.7001
#
# Epoch 00056: val_loss improved from 0.53300 to 0.53012, saving model to best_model1.h5
# Epoch 57/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6083 - accuracy: 0.7123 - f1_m: 0.6966 - precision_m: 0.7424 - recall_m: 0.6582 - val_loss: 0.5260 - val_accuracy: 0.7479 - val_f1_m: 0.7295 - val_precision_m: 0.7634 - val_recall_m: 0.6994
#
# Epoch 00057: val_loss improved from 0.53012 to 0.52598, saving model to best_model1.h5
# Epoch 58/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.6131 - accuracy: 0.7104 - f1_m: 0.6945 - precision_m: 0.7412 - recall_m: 0.6555 - val_loss: 0.5476 - val_accuracy: 0.7373 - val_f1_m: 0.7206 - val_precision_m: 0.7741 - val_recall_m: 0.6753
#
# Epoch 00058: val_loss did not improve from 0.52598
# Epoch 59/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6102 - accuracy: 0.7100 - f1_m: 0.6941 - precision_m: 0.7363 - recall_m: 0.6581 - val_loss: 0.5369 - val_accuracy: 0.7386 - val_f1_m: 0.7308 - val_precision_m: 0.7516 - val_recall_m: 0.7116
#
# Epoch 00059: val_loss did not improve from 0.52598
# Epoch 60/100
# 379/379 [==============================] - 161s 426ms/step - loss: 0.6106 - accuracy: 0.7087 - f1_m: 0.6928 - precision_m: 0.7370 - recall_m: 0.6553 - val_loss: 0.5258 - val_accuracy: 0.7399 - val_f1_m: 0.7271 - val_precision_m: 0.7620 - val_recall_m: 0.6961
#
# Epoch 00060: val_loss improved from 0.52598 to 0.52581, saving model to best_model1.h5
# Epoch 61/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.6052 - accuracy: 0.7123 - f1_m: 0.6985 - precision_m: 0.7412 - recall_m: 0.6619 - val_loss: 0.5248 - val_accuracy: 0.7525 - val_f1_m: 0.7485 - val_precision_m: 0.7649 - val_recall_m: 0.7333
#
# Epoch 00061: val_loss improved from 0.52581 to 0.52480, saving model to best_model1.h5
# Epoch 62/100
# 379/379 [==============================] - 164s 434ms/step - loss: 0.6118 - accuracy: 0.7096 - f1_m: 0.6936 - precision_m: 0.7348 - recall_m: 0.6584 - val_loss: 0.5243 - val_accuracy: 0.7432 - val_f1_m: 0.7290 - val_precision_m: 0.7724 - val_recall_m: 0.6916
#
# Epoch 00062: val_loss improved from 0.52480 to 0.52427, saving model to best_model1.h5
# Epoch 63/100
# 379/379 [==============================] - 165s 435ms/step - loss: 0.5997 - accuracy: 0.7165 - f1_m: 0.7011 - precision_m: 0.7456 - recall_m: 0.6634 - val_loss: 0.5299 - val_accuracy: 0.7393 - val_f1_m: 0.7317 - val_precision_m: 0.7566 - val_recall_m: 0.7090
#
# Epoch 00063: val_loss did not improve from 0.52427
# Epoch 64/100
# 379/379 [==============================] - 162s 426ms/step - loss: 0.6020 - accuracy: 0.7124 - f1_m: 0.7000 - precision_m: 0.7423 - recall_m: 0.6641 - val_loss: 0.5314 - val_accuracy: 0.7360 - val_f1_m: 0.7320 - val_precision_m: 0.7477 - val_recall_m: 0.7176
#
# Epoch 00064: val_loss did not improve from 0.52427
# Epoch 65/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.5997 - accuracy: 0.7147 - f1_m: 0.7017 - precision_m: 0.7453 - recall_m: 0.6647 - val_loss: 0.5127 - val_accuracy: 0.7512 - val_f1_m: 0.7468 - val_precision_m: 0.7675 - val_recall_m: 0.7279
#
# Epoch 00065: val_loss improved from 0.52427 to 0.51270, saving model to best_model1.h5
# Epoch 66/100
# 379/379 [==============================] - 162s 426ms/step - loss: 0.6001 - accuracy: 0.7134 - f1_m: 0.7021 - precision_m: 0.7425 - recall_m: 0.6675 - val_loss: 0.5125 - val_accuracy: 0.7492 - val_f1_m: 0.7364 - val_precision_m: 0.7725 - val_recall_m: 0.7045
#
# Epoch 00066: val_loss improved from 0.51270 to 0.51247, saving model to best_model1.h5
# Epoch 67/100
# 379/379 [==============================] - 165s 434ms/step - loss: 0.5892 - accuracy: 0.7189 - f1_m: 0.7059 - precision_m: 0.7446 - recall_m: 0.6722 - val_loss: 0.5260 - val_accuracy: 0.7360 - val_f1_m: 0.7329 - val_precision_m: 0.7480 - val_recall_m: 0.7189
#
# Epoch 00067: val_loss did not improve from 0.51247
# Epoch 68/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.5981 - accuracy: 0.7158 - f1_m: 0.7051 - precision_m: 0.7444 - recall_m: 0.6712 - val_loss: 0.5442 - val_accuracy: 0.7373 - val_f1_m: 0.7372 - val_precision_m: 0.7491 - val_recall_m: 0.7260
#
# Epoch 00068: val_loss did not improve from 0.51247
# Epoch 69/100
# 379/379 [==============================] - 162s 429ms/step - loss: 0.5951 - accuracy: 0.7180 - f1_m: 0.7069 - precision_m: 0.7456 - recall_m: 0.6736 - val_loss: 0.5193 - val_accuracy: 0.7479 - val_f1_m: 0.7375 - val_precision_m: 0.7744 - val_recall_m: 0.7052
#
# Epoch 00069: val_loss did not improve from 0.51247
# Epoch 70/100
# 379/379 [==============================] - 165s 434ms/step - loss: 0.5895 - accuracy: 0.7175 - f1_m: 0.7064 - precision_m: 0.7431 - recall_m: 0.6746 - val_loss: 0.5061 - val_accuracy: 0.7505 - val_f1_m: 0.7414 - val_precision_m: 0.7638 - val_recall_m: 0.7209
#
# Epoch 00070: val_loss improved from 0.51247 to 0.50614, saving model to best_model1.h5
# Epoch 71/100
# 379/379 [==============================] - 162s 428ms/step - loss: 0.5950 - accuracy: 0.7171 - f1_m: 0.7046 - precision_m: 0.7425 - recall_m: 0.6720 - val_loss: 0.5120 - val_accuracy: 0.7485 - val_f1_m: 0.7357 - val_precision_m: 0.7688 - val_recall_m: 0.7066
#
# Epoch 00071: val_loss did not improve from 0.50614
# Epoch 72/100
# 379/379 [==============================] - 163s 430ms/step - loss: 0.5874 - accuracy: 0.7148 - f1_m: 0.7055 - precision_m: 0.7413 - recall_m: 0.6742 - val_loss: 0.5218 - val_accuracy: 0.7584 - val_f1_m: 0.7482 - val_precision_m: 0.7806 - val_recall_m: 0.7190
#
# Epoch 00072: val_loss did not improve from 0.50614
# Epoch 73/100
# 379/379 [==============================] - 162s 426ms/step - loss: 0.5872 - accuracy: 0.7196 - f1_m: 0.7090 - precision_m: 0.7443 - recall_m: 0.6783 - val_loss: 0.5073 - val_accuracy: 0.7419 - val_f1_m: 0.7350 - val_precision_m: 0.7621 - val_recall_m: 0.7105
#
# Epoch 00073: val_loss did not improve from 0.50614
# Epoch 74/100
# 379/379 [==============================] - 162s 427ms/step - loss: 0.5881 - accuracy: 0.7214 - f1_m: 0.7103 - precision_m: 0.7461 - recall_m: 0.6792 - val_loss: 0.5349 - val_accuracy: 0.7386 - val_f1_m: 0.7370 - val_precision_m: 0.7463 - val_recall_m: 0.7281
#
# Epoch 00074: val_loss did not improve from 0.50614
# Epoch 75/100
# 379/379 [==============================] - 161s 425ms/step - loss: 0.5822 - accuracy: 0.7250 - f1_m: 0.7147 - precision_m: 0.7484 - recall_m: 0.6850 - val_loss: 0.5219 - val_accuracy: 0.7419 - val_f1_m: 0.7376 - val_precision_m: 0.7497 - val_recall_m: 0.7261
#
# Epoch 00075: val_loss did not improve from 0.50614
# Trained

# %% [markdown]
# # MODEL EVALUATION

# %% [markdown]
# ## Generate Predictions

# %%
y_pred_raw = model.predict(test_generator)
y_pred = np.argmax(y_pred_raw, axis=1)
y_true = test.category.values
y_true=y_true[:len(y_pred)]

# %% [markdown]
# ## Metrics Plot Functions

# %%
def plot_history(training):
        """
        Plot training history
        """
        ## Trained model analysis and evaluation
        f, ax = plt.subplots(1,2, figsize=(15,8))
        ax[0].plot(training.history['loss'], label="Loss")
        ax[0].plot(training.history['val_loss'], label="Validation loss")
        ax[0].set_title('Loss')
        ax[0].set_xlabel('Epoch')
        ax[0].set_ylabel('Loss')
        ax[0].legend()

        # Accuracy
        ax[1].plot(training.history['accuracy'], label="Accuracy")
        ax[1].plot(training.history['val_accuracy'], label="Validation accuracy")
        ax[1].set_title('Accuracy')
        ax[1].set_xlabel('Epoch')
        ax[1].set_ylabel('Accuracy')
        ax[1].legend()
        plt.tight_layout()
        plt.show()

def train_report(training):
    print("------- Training Report -----------")
    print("Accuracy: %0.2f" % (np.mean(training.history['accuracy'])*100))
    print("F1 Score: %0.2f" % (np.mean(training.history['f1_m'])*100))
    print("Precision: %0.2f" % (np.mean(training.history['precision_m'])*100))
    print("Recall: %0.2f" % (np.mean(training.history['recall_m'])*100))
    print("Loss: %0.2f" % (np.mean(training.history['loss'])*100))

    print("------- Validation Report -----------")
    print("Accuracy: %0.2f" % (np.mean(training.history['val_accuracy'])*100))
    print("F1 Score: %0.2f" % (np.mean(training.history['val_f1_m'])*100))
    print("Precision: %0.2f" % (np.mean(training.history['val_precision_m'])*100))
    print("Recall: %0.2f" % (np.mean(training.history['val_recall_m'])*100))
    print("Loss: %0.2f" % (np.mean(training.history['val_loss'])*100))

def print_report():
    """
    Predict and evaluate using ground truth from labels
    Test generator did not shuffle 
    and we can use true labels for comparison
    """
    #Print classification report
    print(metrics.classification_report(y_true, y_pred.astype(str), target_names = labels))
    
def print_conf_mtx():
    
    cm = confusion_matrix(y_true.astype(int), y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

    disp.plot(cmap=plt.cm.Blues)
    plt.show()

def multiclass_roc_auc_score(y_test, y_pred, average="weighted"):
    fig, c_ax = plt.subplots(1,1, figsize = (12, 8))
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(labels):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
        
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    c_ax.legend()
    c_ax.set_xlabel('False Positive Rate')
    c_ax.set_ylabel('True Positive Rate')
    c_ax.set_title('ROC Curve')
    print('ROC AUC Score:', roc_auc_score(y_test, y_pred, average=average))
    plt.show()

# %% [markdown]
# ## Results

# %%
train_report(trained)
plot_history(trained)
multiclass_roc_auc_score(y_true.astype(int), y_pred)
print_report()
print_conf_mtx()
# Out:
# ------- Training Report -----------
# Accuracy: 69.21
# F1 Score: 67.69
# Precision: 71.90
# Recall: 64.17
# Loss: 67.92
# ------- Validation Report -----------
# Accuracy: 71.46
# F1 Score: 70.47
# Precision: 73.64
# Recall: 67.81
# Loss: 61.62
# ROC AUC Score: 0.6434897700378517
#                  precision    recall  f1-score   support
#
#           COVID       0.60      0.22      0.32       380
#          Normal       0.74      0.93      0.82      1012
# Viral Pneumonia       0.83      0.73      0.78       124
#
#        accuracy                           0.73      1516
#       macro avg       0.72      0.63      0.64      1516
#    weighted avg       0.71      0.73      0.69      1516
